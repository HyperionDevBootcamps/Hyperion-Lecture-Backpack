# %% [markdown]
# ## Data Frames and Datasets

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# ## Lecture Housekeeping:
#
# - The use of disrespectful language is prohibited in the questions, this is a supportive, learning environment for all - please engage accordingly.
#     - Please review Code of Conduct (in Student Undertaking Agreement) if unsure
# - No question is daft or silly - ask them!
# - There are Q&A sessions midway and at the end of the session, should you wish to ask any follow-up questions.
# - Should you have any questions after the lecture, please schedule a mentor session.
# - For all non-academic questions, please submit a query: [www.hyperiondev.com/support](www.hyperiondev.com/support)

# %% [markdown]
# ## Learning Obectives
#
# - Understand what dataframes are
# - Learn how to manipuate data using Pandas

# %% [markdown]
# ## What are dataframes

# %% [markdown]
# ![creating_dataframe1.png](attachment:creating_dataframe1.png)

# %% [markdown]
# Its a  a table with rows and columns.

# %% [markdown]
# ### What is Pandas?

# %% [markdown]
# Pandas is a Python library used for working with data sets.
#
# It has functions for analyzing, cleaning, exploring, and manipulating data.

# %% [markdown]
# #### Reading a csv file

# %%
import pandas as pd

# %%
dataframe = pd.read_csv('iris_data.csv') # This is how you read a csv file

# %% [markdown]
# #### Viewing the first five row

# %%
dataframe.head() #
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #### Viewing the last five rows

# %%
dataframe.tail() #
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %% [markdown]
# #### The shape of the dataframe

# %%
dataframe.shape
# Out:
# (150, 6)

# %% [markdown]
# #### Summary of the dataset

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# #### Check for datatypes

# %%
dataframe.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
mystring = 'Hello World'
mystring[1]
# Out:
# 'e'

# %% [markdown]
# #### Select rows

# %%
dataframe.loc[5:10] # First rows
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa

# %%
dataframe.loc[[5,10]] # row 1 and 2
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa

# %% [markdown]
# #### Select row and colums

# %%
dataframe.loc[1:5,['SepalLengthCm', 'Species']]
# Out:
#    SepalLengthCm      Species
# 1            4.9  Iris-setosa
# 2            4.7  Iris-setosa
# 3            4.6  Iris-setosa
# 4            5.0  Iris-setosa
# 5            5.4  Iris-setosa

# %%
dataframe.loc[5:10,['SepalLengthCm','PetalLengthCm']]
# Out:
#     SepalLengthCm  PetalLengthCm
# 5             5.4            1.7
# 6             4.6            1.4
# 7             5.0            1.5
# 8             4.4            1.4
# 9             4.9            1.5
# 10            5.4            1.5

# %% [markdown]
# #### View columns

# %%
dataframe.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# #### Descriptive statistics

# %%
dataframe.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# #### Sort Values

# %%
name = [12,34,42,12]
name.sort()
print(name)
# Out:
# [12, 12, 34, 42]

# %%
dataframe.sort_values(by='Id', ascending= False) # by default its ascending
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 149  150            5.9           3.0            5.1           1.8
# 148  149            6.2           3.4            5.4           2.3
# 147  148            6.5           3.0            5.2           2.0
# 146  147            6.3           2.5            5.0           1.9
# 145  146            6.7           3.0            5.2           2.3
# ..   ...            ...           ...            ...           ...
# 4      5            5.0           3.6            1.4           0.2
# 3      4            4.6           3.1            1.5           0.2
# 2      3            4.7           3.2            1.3           0.2
# 1      2            4.9           3.0            1.4           0.2
# 0      1            5.1           3.5            1.4           0.2
#
#             Species
# 149  Iris-virginica
# 148  Iris-virginica
# 147  Iris-virginica
# 146  Iris-virginica
# 145  Iris-virginica
# ..              ...
# ...

# %% [markdown]
# #### Identify Missing Values

# %%
dataframe.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
dataframe.isna() NA
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %% [markdown]
# #### Drop Missing Values

# %%
dataframe.dropna() # Removed from your dataframe
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# #### Number of unique entries over columns

# %%
dataframe.nunique()
# Out:
# Id               150
# SepalLengthCm     35
# SepalWidthCm      23
# PetalLengthCm     43
# PetalWidthCm      22
# Species            3
# dtype: int64

# %%
Link :
